# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder\
                    .appName('Analyzing tweet stories data')\
                    .getOrCreate()

# %%
original_posts = spark.read\
              .format('json')\
              .load('original_posts.json')

# %%
retweet_posts = spark.read\
              .format('json')\
              .load('retweet_posts.json')

# %%
original_posts.createOrReplaceTempView('original_posts')

# %%
retweet_posts.createOrReplaceTempView('retweet_posts')

# %%
spark.sql("""
        SELECT COUNT(user_screen_name) as total_count, user_screen_name 
        FROM original_posts 
        GROUP BY user_screen_name
        ORDER BY total_count DESC
        """).toPandas()
# Out:
#    total_count user_screen_name
# 0          105    DCClothesline
# 1           73     politicususa
# 2           60         TheOnion
# 3           36    BreitbartNews
# 4           17    worldnetdaily
# 5            6  OccupyDemocrats

# %% [markdown]
# ### Find top 25 posts

# %%
top_25 = spark.sql(
    """
        SELECT  COUNT(retweet_status.retweet_status_id) as total, retweet_status.retweet_status_id
        FROM retweet_posts
        GROUP BY retweet_status.retweet_status_id
        ORDER BY total DESC
        LIMIT 25
    """)

# %%
top_25.toPandas()
# Out:
#     total    retweet_status_id
# 0    6560  1095080391084523520
# 1    2717  1095092293537882117
# 2    2670  1095429857905913857
# 3    2536  1095321394299179008
# 4    2448  1095801413568024576
# 5    2362  1095064441912213504
# 6    1619  1095758772268662784
# 7    1397  1095161529308233728
# 8    1323  1095679869856501760
# 9     995  1095695867930136576
# 10    774  1095118130043604998
# 11    741  1095141215815811073
# 12    726  1095129361886384128
# 13    706  1095481162246639621
# 14    706  1095519965309005824
# 15    672  1095906504329363456
# 16    651  1095792053072642049
# 17    603  1095072530149318661
# 18    592  1095056284037140481
# 19    570  1095722445091278848
# 20    491  1095034250527731718
# 21    457  1095672203960561672
# 22    444  1096033085651648514
# 23    395  1095852375993131008
# 24    394  1096099784262381568

# %% [markdown]
# ### Pick post id '1096099784262381568'

# %%
post = spark.sql(
    """
        SELECT * FROM original_posts WHERE id = 1096099784262381568
    """)

post.toPandas().head()
# Out:
#                  created_at                   id  \
# 0  2019-02-14T17:32:07.000Z  1096099784262381568
#
#                                                 text  user_followers_count  \
# 0  Man Hoping Girlfriend Doesn't Notice Valentine...              11032690
#
#    user_friends_count   user_id user_screen_name  user_verified
# 0                  14  14075928         TheOnion           True

# %%
post_retweets = spark.sql(
    """
        SELECT * FROM retweet_posts WHERE retweet_status.retweet_status_id=1096099784262381568
    """)
post_retweets.toPandas().head()
# Out:
#                  created_at                   id  \
# 0  2019-02-14T17:35:01.000Z  1096100512062009344
# 1  2019-02-14T17:38:36.000Z  1096101416295374849
# 2  2019-02-14T17:40:32.000Z  1096101899705729029
# 3  2019-02-14T18:29:36.000Z  1096114249800314881
# 4  2019-02-14T17:43:29.000Z  1096102641854078977
#
#                                       retweet_status  \
# 0  (1096099784262381568, Man Hoping Girlfriend Do...
# 1  (1096099784262381568, Man Hoping Girlfriend Do...
# 2  (1096099784262381568, Man Hoping Girlfriend Do...
# 3  (1096099784262381568, Man Hoping Girlfriend Do...
# 4  (1096099784262381568, Man Hoping Girlfriend Do...
#
#                                                 text  user_followers_count  \
# 0  RT @TheOnion: Man Hoping Girlfriend Doesn't No...                    36
# 1  RT @TheOnion: Man Hoping Girlfriend Doesn't No...                   351
# 2  RT @TheOnion: Man Hoping Girlfriend Doesn't No...                   193
# 3  RT @TheOnion: Man Hoping Girlfriend Doesn't No...                   399
# 4  RT @TheOnion: Man Hoping Girlfriend Doesn't No...                   222
#
#    user_friends_count     user_id user_screen_name  user_verified
# 0                 112    27731830        andhraite          False
# 1                1258   389687876        ColmMagan          False
# 2                 975   957342374    GenisisDancer          False
# 3                 282  2717357373       MIKEYJEAN1          False
# 4                 282   731252286        PBSamlish          False

# %%
post.coalesce(1).write.format('json').save('post.json')

# %%
post_retweets.coalesce(1).write.format('json').save('post_retweets.json')
